# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
for k in range(4):
    df_rnn=pd.read_csv("./Baselines/LSTM_"+str(k)+".csv")
    df_rnn=df_rnn.T
    df_rnn.rename({"P&L": "Profit & Loss (P&L)", "Annualized VOlatiliy": "Annualized Volatility","Sharpe":"Sharpe Ratio","Sortino":"Sortino Ratio","Maximum Drawdown Days":"Maximum DrawDown Duration","Ratio Profitability":"Ratio Average Profit/Loss"}, axis='index',inplace=True)
    df_rnn["Performance Indicator"]=df_rnn.index
    df_rnn.rename(columns={0: "Google", 1: "Apple",2: "IBM",3: "Baidu",4: "JPMorgan Chase",5: "BlackRock",6: "ExxonMobil",7: "Volkswagen",8: "Toyota",9: "Coca Cola",10:"McDonalds"},inplace=True)
    df_rnn = df_rnn.iloc[1: , :]
    df_rnn.reset_index(drop = True)
    print(k)
    df_rnn.to_csv("./Baselines/LSTM_clean_"+str(k)+".csv")
# Out:
# 0
# 1
# 2
# 3

# %%
# big_vec=[]
# for i in range(4):
#     print(i)
    
#     df_bh=pd.read_csv("./Baselines/Buy and Hold_"+str(i)+".csv")
#     df_sh=pd.read_csv("./Baselines/Sell and Hold_"+str(i)+".csv")
#     df_mr=pd.read_csv("./Baselines/Mean Reversion Moving Averages_"+str(i)+".csv")
#     df_tf=pd.read_csv("./Baselines/Trend Following Moving Averages_"+str(i)+".csv")
#     df_rnn=pd.read_csv("./Baselines/LSTM_"+str(i)+".csv")
#     vec=[]
#     for j in range(2):
#         print(j)
#         vec.append(df_bh.loc[j:j].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
#         vec.append(df_sh.loc[j:j].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
#         vec.append(df_tf.loc[j:j].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
#         vec.append(df_mr.loc[j:j].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
#         vec.append(10*df_rnn.T.loc["P&L"].astype(float))

# %%
#Period 0: 2010-2018-2022

# %%
for i in range(4):
    print(i)
    
    df_bh=pd.read_csv("./Baselines/Buy and Hold_"+str(i)+".csv")
    df_sh=pd.read_csv("./Baselines/Sell and Hold_"+str(i)+".csv")
    df_mr=pd.read_csv("./Baselines/Mean Reversion Moving Averages_"+str(i)+".csv")
    df_tf=pd.read_csv("./Baselines/Trend Following Moving Averages_"+str(i)+".csv")
    df_rnn=pd.read_csv("./Baselines/LSTM_"+str(i)+".csv")








    fig = go.Figure()

    fig.add_trace(go.Scatter(x=df_bh.loc[:0].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Buy & Hold'))
    fig.add_trace(go.Scatter(x=df_sh.loc[:0].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers', 
                         name='Sell & Hold'))
    fig.add_trace(go.Scatter(x=df_tf.loc[:0].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Mean Reversion'))
    fig.add_trace(go.Scatter(x=df_mr.loc[:0].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Trend Following'))
    fig.add_trace(go.Scatter(x=10*df_rnn.T.loc["P&L"].astype(float), y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='RNN'))

    fig.update_layout(
        xaxis=dict(
            showline=True,
            showgrid=True,
            showticklabels=True,
            linecolor='white',
            linewidth=2
        ),
        yaxis=dict(
            title_text='Stock',
            titlefont=dict(
                family='Rockwell',
                size=12,
                color='white',
            ),
            showline=True,
            showgrid=True,
            showticklabels=True,
            linecolor='white',
            linewidth=2,
            ticks='outside',
            tickfont=dict(
                family='Rockwell',
                size=12,
                color='white',
            ),
        ),
        showlegend=True,
        template = 'plotly_dark'

    )



    annotations = []
    annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                                  xanchor='left', yanchor='bottom',
                                  text="Period "+str(i)+': P and L',
                                  font=dict(family='Rockwell',
                                            size=26,
                                            color='white'),
                                  showarrow=False))
    fig.update_layout(annotations=annotations)

    fig.show()
    
    
    


    fig = go.Figure()

    fig.add_trace(go.Scatter(x=df_bh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Buy & Hold'))
    fig.add_trace(go.Scatter(x=df_sh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers', 
                         name='Sell & Hold'))
    fig.add_trace(go.Scatter(x=df_tf.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Mean Reversion'))
    fig.add_trace(go.Scatter(x=df_mr.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0], y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='Trend Following'))
    fig.add_trace(go.Scatter(x=df_rnn.T.loc["Annualized Return"].astype(float), y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
                         mode='markers',
                         name='RNN'))

    fig.update_layout(
        xaxis=dict(
            showline=True,
            showgrid=True,
            showticklabels=True,
            linecolor='white',
            linewidth=2
        ),
        yaxis=dict(
            title_text='Close (USD)',
            titlefont=dict(
                family='Rockwell',
                size=12,
                color='white',
            ),
            showline=True,
            showgrid=True,
            showticklabels=True,
            linecolor='white',
            linewidth=2,
            ticks='outside',
            tickfont=dict(
                family='Rockwell',
                size=12,
                color='white',
            ),
        ),
        showlegend=True,
        template = 'plotly_dark'

    )



    annotations = []
    annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                                  xanchor='left', yanchor='bottom',
                                  text='2018-2022. Annual Return',
                                  font=dict(family='Rockwell',
                                            size=26,
                                            color='white'),
                                  showarrow=False))
    fig.update_layout(annotations=annotations)

    fig.show()
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda31\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# ~\anaconda31\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda31\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P&L'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15712\3742525959.py in <module>
#      29                          mode='markers',
#      30                          name='Trend Following'))
# ---> 31     fig.add_trace(go.Scatter(x=10*df_rnn.T.loc["P&L"].astype(float), y=list(df_bh.loc[:0].iloc[:, 2:13].keys()),
#      32                          mode='markers',
#      33                          name='RNN'))
#
# ~\anaconda31\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda31\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda31\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\anaconda31\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# ~\anaconda31\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
# -> 3805                 raise KeyError(key) from err
#    3806             except TypeError:
#    3807                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'P&L'

# %%
plt.scatter(list(df_bh.loc[:0].iloc[:, 2:13].keys()), df_bh.loc[:0].iloc[:, 2:13].to_numpy().astype(float)[0])
plt.scatter(list(df_sh.loc[:0].iloc[:, 2:13].keys()), df_sh.loc[:0].iloc[:, 2:13].to_numpy().astype(float)[0])
plt.scatter(list(df_tf.loc[:0].iloc[:, 2:13].keys()), df_tf.loc[:0].iloc[:, 2:13].to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), df_mr.loc[:0].iloc[:, 2:13].to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), 10*df_rnn.T.loc["P&L"].astype(float))

plt.legend(['B&H', 'S&H','TF','MR',"RNN"])
plt.xticks(rotation = 90)

# %%
df_bh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack()

# %%
plt.scatter(list(df_bh.loc[:0].iloc[:, 2:13].keys()), df_bh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_sh.loc[:0].iloc[:, 2:13].keys()), df_sh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_tf.loc[:0].iloc[:, 2:13].keys()), df_tf.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), df_mr.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), df_rnn.T.loc["Annualized Return"].astype(float))


plt.legend(['B&H', 'S&H','TF','MR',"RNN"])
plt.xticks(rotation = 90)

# %%
plt.scatter(list(df_bh.loc[:0].iloc[:, 2:13].keys()), df_bh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_sh.loc[:0].iloc[:, 2:13].keys()), df_sh.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_tf.loc[:0].iloc[:, 2:13].keys()), df_tf.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), df_mr.loc[1:1].iloc[:, 2:13].stack().str.replace("%", "").unstack().to_numpy().astype(float)[0])
plt.scatter(list(df_mr.loc[:0].iloc[:, 2:13].keys()), df_rnn.T.loc["Annualized Return"].astype(float))

# %% [markdown]
# ## New Code

# %%
import os
import pandas as pd
from os import listdir
from os.path import isfile, join
import numpy as np

def load_data():
    root_path = r"C:\Users\carlo\Downloads\analysis-20221207T102828Z-001\analysis"
    folders = listdir(root_path)
    paths = [os.path.join(root_path , ii) for ii in folders]
    df_list = []
    for path in paths:
        for f in listdir(path):
            data = pd.read_csv(join(path, f)).drop('Unnamed: 0',axis=1)
            data['folder'] = path.split('\\')[-1]
            data['filename'] = f.split('.')[0].split('_')[0]
            data['period'] = f.split('.')[0].split('_')[-1]
            df_list.append(data)
    df = pd.concat(df_list)
    return df

# %%
df = load_data()
stocks_col = ['Google', 'Apple', 'IBM', 'Baidu',
           'JPMorgan Chase', 'BlackRock', 'ExxonMobil', 'Volkswagen', 'Toyota',
           'Coca Cola', 'McDonalds']
    
df.loc[1,stocks_col] = df.loc[1,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[2,stocks_col] = df.loc[2,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[5,stocks_col] = df.loc[5,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[6,stocks_col] = df.loc[6,stocks_col].apply(lambda x: [ii.strip(' days') if type(ii)==str else ii for ii in x])
df.loc[7,stocks_col] = df.loc[7,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df[stocks_col] = df[stocks_col].astype(float)
df['mean'] = df[stocks_col].apply(np.mean,axis=1)
df['var'] = df[stocks_col].apply(np.var,axis=1)

# %%
df
# Out:
#         Performance Indicator      Google        Apple        IBM       Baidu  \
# 0         Profit & Loss (P&L)  212208.000  1250780.000 -11408.000 -289712.000
# 1           Annualized Return      11.300       20.640      1.650     -18.050
# 2       Annualized Volatility      30.550       32.870     27.370      50.170
# 3                Sharpe Ratio       0.459        0.929      0.062      -0.255
# 4               Sortino Ratio       0.611        1.255      0.076      -0.389
# ..                        ...         ...          ...        ...         ...
# 5            Maximum DrawDown      61.930       58.450     18.770      76.470
# 6   Maximum DrawDown Duration     545.000      510.000     66.000     164.000
# 7               Profitability      38.330       40.000     63.640      31.710
# 8   Ratio Average Profit/Loss       0.950        1.071      0.974       1.708
# 9                    Skewness      -0.256        0.011     -0.737      -0.566
#
#     JPMorgan Chase  BlackRock  ExxonMobil  Volkswagen    Toyota  Coca Cola  \
# 0        27030.000  38537.000   62284.000  -35268.000  5692.000  62008.000
# 1            6.450      7.160      11.370       3.300     3.070      7.580
# 2           32.060     31.610      33.810      36.720    22.520     21.530
# 3            0.228      0.260       0.418       0.095     0.145      0.407
# 4            0.313      0.336       0.593       0.134     0.203      0.483
# ..             ...        ...         ...         ...       ...        ...
# 5           56.610     58.480      20.510      47.600    40.350     25.510
# 6          598.000    362.000      24.000     149.000    83.000    184.000
# 7           36.210     42.860      66.670      48.310    53.330     34.780
# 8            1.082      1.014       9.483       1.126     1.132      1.698
# 9            0.629      0.021       0.273       0.232    -0.060     -0.192
#
#      McDonalds                                  folder      filename period  \
# 0   177908.000                               Baselines  Buy and Hold      0
# 1       11.070                               Baselines  Buy and Hold      0
# 2       23.900                               Baselines  Buy and Hold      0
# 3        0.572                               Baselines  Buy and Hold      0
# 4        0.728                               Baselines  Buy and Hold      0
# ..         ...                                     ...           ...    ...
# 5       17.670  with context-30days-lookback-512-nodes         TDRQN      2
# 6       43.000  with context-30days-lookback-512-nodes         TDRQN      2
# 7      100.000  with context-30days-lookback-512-nodes         TDRQN      2
# 8          inf  with context-30days-lookback-512-nodes         TDRQN      2
# 9       -0.002  with context-30days-lookback-512-nodes         TDRQN      2
#
#             mean           var
# 0   1.363690e+05  1.392593e+11
# 1   5.958182e+00  8.310787e+01
# 2   3.119182e+01  5.800654e+01
# 3   3.018182e-01  8.706779e-02
# 4   3.948182e-01  1.614272e-01
# ..           ...           ...
# 5   4.385000e+01  3.820716e+02
# 6   2.480000e+02  4.235018e+04
# 7   5.053091e+01  3.652989e+02
# 8            inf           NaN
# 9  -5.881818e-02  1.323663e-01
#
# [360 rows x 17 columns]

# %%
df.period.value_counts().sum()
# Out:
# 360

# %%
df.period.value_counts()
# Out:
# 0    110
# 1    110
# 2     90
# 3     50
# Name: period, dtype: int64

# %%
import seaborn as sns

# %%
df.groupby(by=["filename","period"]).mean()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_15712\484858433.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                                                Google         Apple  \
# filename                        period
# Buy and Hold                    0                 NaN           NaN
#                                 1                 NaN           NaN
#                                 2                 NaN           NaN
#                                 3                 NaN           NaN
# LSTM                            0          970.871991  1.522080e+03
#                                 1         1041.043399  1.577642e+03
#                                 2          476.275898  7.845037e+02
#                                 3          353.199332  6.238989e+02
# Mean Reversion Moving Averages  0       -10123.459700 -9.455895e+03
#                                 1        -5343.417600 -4.468395e+03
#                                 2        -1144.924100 -1.858840e+03
#                                 3         4263.830300 -5.851619e+03
# Sell and Hold                   0                 NaN           NaN
#                                 1           83.336600           NaN
#                                 2                 NaN           NaN
#                                 3                 NaN           NaN
# TDQN                            0        43543.169600 -9.956034e+05
#                                 1        31190.310700  5.383677e+03
#                                 2         8144.557700           NaN
# TDRQN                           0       104795.278133 -4.308561e+06
#                                 1        31638.701967  3.493801e+04
#                                 2       -58295.004300 -1.727915e+04
# Trend Following Moving Averages 0        -6168.829300  7.140987e+04
#                                 1       -23850.398400  8.881818e+04
#                                 2         5197.489900  3.087090e+04
#                                 3        -3985.527900 -7.501050e+01
#
#                                                  IBM         Baidu  \
# filename                        period
# Buy and Hold                    0       -1085.227700 -2.891734e+04
#                                 1       -1552.127700 -2.465771e+05
#                                 2                NaN -5.584721e+03
#                                 3                NaN           NaN
# LSTM                            0          -6.499534 -4.694980e+02
#                                 1         -24.289583 -4.685759e+02
#                                 2         209.343967 -1.373153e+01
#                                 3         232.321378  4.490574e+02
# Mean Reversion Moving Averages  0       15109.115800 -6.024894e+04
#                                 1       -6392.423100 -4.178544e+04
#                                 2        4366.902100 -3.071860e+04
#                                 3       -2013.085200 -1.329393e+04
# Sell and Hold                   0                NaN  3.254880e+01
#                                 1                NaN  4.488000e-01
#                                 2       -2171.978800           NaN
#                                 3        -536.389600           NaN
# TDQN                            0          79.570067 -4.168043e+05
#                                 1       -9635.268300  1.128188e+05
#                                 2                NaN           NaN
# TDRQN                           0       -6352.534600 -6.323689e+06
#                                 1       -4502.578600 -1.100605e+06
#                                 2       -4476.362600 -8.451712e+04
# Trend Following Moving Averages 0       -5609.908600 -8.276155e+03
#                                 1       -5738.240200  7.308333e+04
#                                 2       -6212.085900  1.105942e+04
#                                 3        -950.914700 -7.349500e+00
#
#                                         JPMorgan Chase     BlackRock  \
# filename                        period
# Buy and Hold                    0                  NaN           NaN
#                                 1                  NaN           NaN
#                                 2                  NaN           NaN
#                                 3                  NaN           NaN
# LSTM                            0           207.215915    175.609303
#                                 1            71.792276      2.090873
#                                 2           436.158456    204.540457
#                                 3           721.746892    482.225323
# Mean Reversion Moving Averages  0           990.757400 -22240.291700
#                                 1         -7145.376500 -14537.229000
#                                 2          6687.241400  -9540.173600
#                                 3         -3875.231800  -5562.637100
# Sell and Hold                   0            42.126600     34.760500
#                                 1            50.026600     55.060500
#                                 2            41.497000     35.778900
#                                 3         -3965.134100  -2497.533400
# TDQN                            0                  NaN -15057.020733
#                                 1          6745.359100  -6645.513067
#                                 2           201.503500           NaN
# TDRQN                           0         -4795.336500   1608.280233
#                                 1        -18939.973167  -7022.464200
#                                 2        -11826.515350   -799.456600
# Trend Following Moving Averages 0        -12276.577000  -7530.321700
#                                 1         -6390.405100  -3054.811100
#                                 2         -2926.712200   -535.714700
#                                 3          1139.903500    -98.849100
#
#                                            ExxonMobil    Volkswagen  \
# filename                        period
# Buy and Hold                    0                 NaN -3.485533e+03
#                                 1                 NaN -8.948833e+03
#                                 2                 NaN -4.357934e+02
#                                 3                 NaN           NaN
# LSTM                            0          405.362796 -1.137881e+02
#                                 1          420.245122 -1.469903e+02
#                                 2         1255.462709  1.888891e+02
#                                 3          149.693813  6.803599e+02
# Mean Reversion Moving Averages  0       -12511.037500 -1.328096e+04
#                                 1       -23499.635400 -5.187662e+03
#                                 2        -6226.766800 -1.994563e+04
#                                 3         1078.901200  1.742104e+04
# Sell and Hold                   0        -3744.664700           NaN
#                                 1        -3012.464700           NaN
#                                 2       -14222.459500           NaN
#                                 3          -76.418200  4.920460e+01
# TDQN                            0                 NaN -8.419311e+03
#                                 1        25577.890433 -4.111869e+04
#                                 2        10844.959500           NaN
# TDRQN                           0      -208640.489900 -1.162917e+07
#                                 1       -11297.336767 -2.704030e+04
#                                 2                 NaN -2.528283e+04
# Trend Following Moving Averages 0         3754.642500 -9.192664e+03
#                                 1         2162.742500 -1.101463e+05
#                                 2         -198.015300 -1.282481e+04
#                                 3         2560.986400 -8.706900e+03
#
#                                               Toyota    Coca Cola  \
# filename                        period
# Buy and Hold                    0                NaN          NaN
#                                 1                NaN          NaN
#                                 2                NaN          NaN
#                                 3                NaN          NaN
# LSTM                            0         -17.070676   269.443791
#                                 1          -9.292731   254.458364
#                                 2         149.966369   341.181767
#                                 3         123.499491   110.816542
# Mean Reversion Moving Averages  0       -5636.278800  3285.593200
#                                 1      -10563.068200  7305.596100
#                                 2       10800.618500  7661.745600
#                                 3        -708.253100  3299.642000
# Sell and Hold                   0         -84.136900 -1021.157600
#                                 1         -39.536900   -22.957600
#                                 2        -240.089600  -206.339400
#                                 3        -728.148900   -51.755900
# TDQN                            0        -118.805267  3998.788900
#                                 1       -7266.827233  2101.340267
#                                 2         969.857100  3412.571800
# TDRQN                           0      -37835.950967  4961.945400
#                                 1      -28426.621667 -5076.647333
#                                 2        1477.847700          NaN
# Trend Following Moving Averages 0       -6722.567000 -1867.376600
#                                 1       -5434.867000 -2031.279600
#                                 2         181.474100 -1943.409900
#                                 3       -3119.591400 -1966.112200
#
#                                            McDonalds          mean  \
# filename                        period
# Buy and Hold                    0                NaN           NaN
#                                 1                NaN           NaN
#                                 2                NaN           NaN
#                                 3                NaN           NaN
# LSTM                            0         550.887964  3.176923e+02
#                                 1         521.155062  2.944799e+02
#                                 2         415.636814  4.043843e+02
#                                 3         284.843983  3.828784e+02
# Mean Reversion Moving Averages  0       -7791.487400 -1.108208e+04
#                                 1      -10519.732300 -1.110334e+04
#                                 2       -2013.022200 -3.811950e+03
#                                 3        -284.890200 -5.023850e+02
# Sell and Hold                   0          51.181400           NaN
#                                 1                NaN           NaN
#                                 2          60.798300           NaN
#                                 3        -835.686700           NaN
# TDQN                            0       23703.587833           NaN
#                                 1        4953.754233  1.128226e+04
#                                 2                NaN           NaN
# TDRQN                           0       12891.926700 -2.035890e+06
#                                 1        4243.690233 -1.029173e+05
#                                 2                NaN           NaN
# Trend Following Moving Averages 0       -1457.364900  1.460250e+03
#                                 1        2712.645800  9.209661e+02
#                                 2       -4599.026800  1.642682e+03
#                                 3        3568.925200 -1.058222e+03
#
#                                                  var
# filename                        period
# Buy and Hold                    0       1.547325e+10
#                                 1       5.073684e+11
#                                 2       2.953813e+09
#                                 3       4.077838e+08
# LSTM                            0       2.785295e+06
#                                 1       3.118705e+06
#                                 2       1.159371e+06
#                                 3       4.726441e+05
# Mean Reversion Moving Averages  0       3.307004e+09
#                                 1       1.453577e+09
#                                 2       1.420561e+09
#                                 3       5.392056e+08
# Sell and Hold                   0       1.485648e+07
#                                 1       8.682824e+06
#                                 2       1.847361e+08
#                                 3       1.722949e+07
# TDQN                            0       2.859804e+12
#                                 1       4.888514e+10
#                                 2       2.865644e+09
# TDRQN                           0       6.410867e+14
#                                 1       1.484776e+12
#                                 2       2.037016e+10
# Trend Following Moving Averages 0       5.072729e+09
#                                 1       2.369405e+10
#                                 2       1.193235e+09
#                                 3       1.042728e+08

# %%
df[df["Performance Indicator"]=="Profit & Loss (P&L)"].Google.to_numpy().astype(float)
# Out:
# array([ 2.12208000e+05,  6.83484000e+05,  1.08635000e+05,  1.06938000e+05,
#         9.33069109e+03,  1.00265999e+04,  4.36015556e+03,  3.38074934e+03,
#        -1.02493000e+05, -5.45490000e+04, -1.17440000e+04,  4.24240000e+04,
#         1.04100000e+03, -0.00000000e+00,  8.83000000e+02,  4.14000000e+02,
#        -6.29340000e+04, -2.39174000e+05,  5.17560000e+04, -4.02400000e+04,
#        -8.46200000e+04, -5.15800000e+03,  1.35778000e+06,  4.23785000e+05,
#         7.43473000e+05,  4.43284000e+05,  1.86839000e+05,  7.59339000e+05,
#         5.41540000e+04, -5.08542000e+05,  6.46289000e+05,  4.96592000e+05,
#        -2.48980000e+04,  1.02561600e+06,  4.70326000e+05, -6.58345000e+05])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pnl=df[df["Performance Indicator"]=="Profit & Loss (P&L)"]

# %%
df.columns
# Out:
# Index(['Performance Indicator', 'Google', 'Apple', 'IBM', 'Baidu',
#        'JPMorgan Chase', 'BlackRock', 'ExxonMobil', 'Volkswagen', 'Toyota',
#        'Coca Cola', 'McDonalds', 'folder', 'filename', 'period', 'mean',
#        'var'],
#       dtype='object')

# %% [markdown]
# ## Profit and Losses

# %%
df_pnl[['Google', 'Apple', 'IBM', 'Baidu',
       'JPMorgan Chase', 'BlackRock', 'ExxonMobil', 'Volkswagen', 'Toyota',
       'Coca Cola', 'McDonalds']] = df_pnl[['Google', 'Apple', 'IBM', 'Baidu',
       'JPMorgan Chase', 'BlackRock', 'ExxonMobil', 'Volkswagen', 'Toyota',
       'Coca Cola', 'McDonalds']].astype(float)
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_15712\4003069811.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.boxplot(data=df_pnl , showfliers = False)
# Out:
# C:\Users\carlo\anaconda31\lib\site-packages\seaborn\categorical.py:82: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# <AxesSubplot:>

# %%
sns.boxplot(data=df_pnl, x='IBM', y='period', showfliers = False)
# Out:
# <AxesSubplot:xlabel='IBM', ylabel='period'>

# %%
for i in df_pnl.columns:
    print(i)
# Out:
# Performance Indicator
# Google
# Apple
# IBM
# Baidu
# JPMorgan Chase
# BlackRock
# ExxonMobil
# Volkswagen
# Toyota
# Coca Cola
# McDonalds
# folder
# filename
# period
# mean
# var

# %%
cols_to_anal=["Google",
"Apple",
"IBM",
"Baidu",
"JPMorgan Chase",
"BlackRock",
"ExxonMobil",
"Volkswagen",
"Toyota",
"Coca Cola",
"McDonalds"]

# %%
df_temp=pd.DataFrame()
df_dd=pd.DataFrame()
for i in cols_to_anal:
    df_temp[["Value","folder","filename","period"]]=df_pnl[["Google","folder","filename","period"]]
    df_dd=pd.concat([df_dd,df_temp])
    
df_dd=df_dd[df_dd.Value < 1000000]
df_dd=df_dd[df_dd.Value > -1000000]

# %%
df_dd=df_dd[df_dd.Value < 1000000]
df_dd=df_dd[df_dd.Value > -1000000]

# %%
sns.boxplot(data=df_dd, x="Value", y="filename",showfliers = False)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='filename'>

# %%
sns.boxplot(data=df_dd, x="Value", y="period",showfliers = False)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='period'>

# %%
f = plt.figure(figsize=(15, 10))
sns.boxplot(data=df_dd, x="period", y="Value", hue="filename",palette="viridis",showfliers = False, orient="v")
plt.xticks(rotation=90)
plt.ylabel("Annualized Return")
# Out:
# Text(0, 0.5, 'Annualized Return')

# %%
df_dd[df_dd.filename=="TDQN"].Value.hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df_dd[df_dd.filename=="LSTM"].Value,kde=True,bins=32)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Count'>

# %%
df_dd[df_dd.filename=="LSTM"].value_counts()
# Out:
# Value         folder     filename  period
# 3380.749342   Baselines  LSTM      3         11
# 4360.155563   Baselines  LSTM      2         11
# 9330.691088   Baselines  LSTM      0         11
# 10026.599930  Baselines  LSTM      1         11
# dtype: int64

# %%
sns.histplot(df_dd[df_dd.filename=="TDRQN"].Value,kde=True)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Count'>

# %%
df.folder.value_counts()
# Out:
# Baselines                                    200
# no context-30days-lookback-512-nodes          60
# with context-30days-lookback-512-nodes        60
# context-50days-lookback-512nodes_gamma_09     40
# Name: folder, dtype: int64

# %% [markdown]
# ## Annualized return

# %%
df_ar=df[df["Performance Indicator"]=="Annualized Return"]

# %%
df_temp=pd.DataFrame()
df_dd=pd.DataFrame()
for i in cols_to_anal:
    df_temp[["Value","folder","filename","period"]]=df_ar[[i,"folder","filename","period"]]

    df_dd=pd.concat([df_dd,df_temp])

# %%
df_dd
# Out:
#         Value                                  folder      filename period
# 1   11.300000                               Baselines  Buy and Hold      0
# 1   11.300000                               Baselines  Buy and Hold      1
# 1   12.660000                               Baselines  Buy and Hold      2
# 1   16.430000                               Baselines  Buy and Hold      3
# 1   14.611763                               Baselines          LSTM      0
# ..        ...                                     ...           ...    ...
# 1  -21.810000  with context-30days-lookback-512-nodes          TDQN      1
# 1   17.080000  with context-30days-lookback-512-nodes          TDQN      2
# 1   -5.530000  with context-30days-lookback-512-nodes         TDRQN      0
# 1    6.440000  with context-30days-lookback-512-nodes         TDRQN      1
# 1   16.440000  with context-30days-lookback-512-nodes         TDRQN      2
#
# [396 rows x 4 columns]

# %%
df_dd=df_dd[df_dd.Value < 100]
df_dd=df_dd[df_dd.Value > -35]

# %%
df_dd=df_dd[(df_dd.period != "TDQN") & (df_dd.period != "TDRQN")]

# %%
f = plt.figure(figsize=(10, 8))
sns.boxplot(data=df_dd, x="period", y="Value", hue="filename",palette="viridis",showfliers = False, orient="v")
plt.xticks(rotation=90)
plt.ylabel("Annualized Return")
# Out:
# Text(0, 0.5, 'Annualized Return')

# %%
f = plt.figure(figsize=(15, 10))
sns.boxplot(data=df_dd, x="period", y="Value", hue="filename",palette="viridis",showfliers = False, orient="v")
plt.xticks(rotation=90)
plt.ylabel("Annualized Return")
# Out:
# Text(0, 0.5, 'Annualized Return')

# %%
sns.boxplot(data=df_dd, x="Value", y="period",palette="viridis")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='period'>

# %%
from joypy import joyplot

joyplot(df_dd, by='filename', column='Value', colormap=sns.color_palette("crest", as_cmap=True));
plt.xlabel('Annualized Return');

# %% [markdown]
# ## Annualized Volatility

# %%
df_vo=df[df["Performance Indicator"]=="Annualized Volatility"]
df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN")]

# %%
df_temp=pd.DataFrame()
df_vo1=pd.DataFrame()
for i in cols_to_anal:
    df_temp[["Value","folder","filename","period"]]=df_vo[[i,"folder","filename","period"]]
    df_vo1=pd.concat([df_vo1,df_temp])

# %%
f = plt.figure(figsize=(15, 10))
sns.boxplot(data=df_vo1, x="period", y="Value", hue="filename",palette="viridis",showfliers = False, orient="v")
plt.xticks(rotation=90)
plt.ylabel("Annualized Volatility")

# %%
## Profitability

# %%
for i in df["Performance Indicator"].unique():
    print(i)

# %%
df["Performance Indicator"].unique()
# Out:
# array(['Profit & Loss (P&L)', 'Annualized Return',
#        'Annualized Volatility', 'Sharpe Ratio', 'Sortino Ratio',
#        'Maximum DrawDown', 'Maximum DrawDown Duration', 'Profitability',
#        'Ratio Average Profit/Loss', 'Skewness'], dtype=object)

# %%
df_vo1["Value"].where(df_vo1.filename=="LSTM",df_vo1[df_vo1.filename=="LSTM"]["Value"]*10 + 0.2,inplace=True)

# %%
df[(df.filename=="LSTM")  & (df["Performance Indicator"]=="Sharpe Ratio")][cols_to_anal] = df[(df.filename=="LSTM")  & (df["Performance Indicator"]=="Sharpe Ratio")][cols_to_anal]*10+0.2

# %%
for j in df["Performance Indicator"].unique():
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period"]]=df_vo[[i,"folder","filename","period"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    
    if j=="Ratio Average Profit/Loss": ##Filtering out outliers
        df_vo1=df_vo1[df_vo1["Value"]<10]
    if j=="Annualized Return": ##Filtering out outliers
        df_vo1=df_vo1[df_vo1["Value"]>-80]
    if j=="Maximum DrawDown": ##Filtering out outliers
        df_vo1=df_vo1[df_vo1["Value"]>-20]
    if j=="Profitability": ##Filtering out outliers
        df_vo1=df_vo1[(df_vo1["Value"]>-70) & (df_vo1["Value"]<70)]
    if j=="Annualized Volatility": ##Filtering out outliers
        df_vo1=df_vo1[(df_vo1["Value"]<100) ]


        
    df_vo1=df_vo1.rename(columns={"filename": "Algorithm"})
    f = plt.figure(figsize=(10, 8))
    sns.boxplot(data=df_vo1, x="period", y="Value", hue="Algorithm",palette="viridis",showfliers = False, orient="v")
    plt.xticks(rotation=90)
    plt.ylabel(j)
    plt.title(j)

# %%
df_vo1
# Out:
#        Value                                  folder     Algorithm period
# 3   0.459000                               Baselines  Buy and Hold      0
# 3   0.459000                               Baselines  Buy and Hold      1
# 3   0.468000                               Baselines  Buy and Hold      2
# 3  -0.005209                               Baselines          LSTM      0
# 3  -0.009519                               Baselines          LSTM      1
# ..       ...                                     ...           ...    ...
# 3  -0.594000  with context-30days-lookback-512-nodes          TDQN      1
# 3   1.086000  with context-30days-lookback-512-nodes          TDQN      2
# 3  -0.203000  with context-30days-lookback-512-nodes         TDRQN      0
# 3   0.309000  with context-30days-lookback-512-nodes         TDRQN      1
# 3   1.040000  with context-30days-lookback-512-nodes         TDRQN      2
#
# [341 rows x 4 columns]

# %%
for j in df["Performance Indicator"].unique():
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period"]]=df_vo[[i,"folder","filename","period"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    
    if j=="Ratio Average Profit/Loss": ##Filtering out outliers
        df_vo1=df_vo1[df_vo1["Value"]<10]
    if j=="Annualized Return": ##Filtering out outliers
        df_vo1=df_vo1[df_vo1["Value"]>-80]    
        
    df_vo1=df_vo1.rename(columns={"filename": "Algorithm"})
    f = plt.figure(figsize=(10, 8))
    sns.boxplot(data=df_vo1, x="period", y="Value", hue="Algorithm",palette="viridis",showfliers = False, orient="v")
    plt.xticks(rotation=90)
    plt.ylabel(j)
    plt.title(j)

# %%
df_vo1.rename(columns={"filename":"Algorithm"})
# Out:
#        Value                                  folder     Algorithm period
# 9  -0.082000                               Baselines  Buy and Hold      0
# 9  -0.082000                               Baselines  Buy and Hold      1
# 9  -0.086000                               Baselines  Buy and Hold      2
# 9  -0.192787                               Baselines          LSTM      0
# 9  -0.069733                               Baselines          LSTM      1
# ..       ...                                     ...           ...    ...
# 9   0.454000  with context-30days-lookback-512-nodes          TDQN      1
# 9  -0.006000  with context-30days-lookback-512-nodes          TDQN      2
# 9  -2.305000  with context-30days-lookback-512-nodes         TDRQN      0
# 9  -2.293000  with context-30days-lookback-512-nodes         TDRQN      1
# 9  -0.002000  with context-30days-lookback-512-nodes         TDRQN      2
#
# [341 rows x 4 columns]

# %%
df[df.period=="TDQN"]

# %% [markdown]
# # Gamma

# %%
def load_data2():
    root_path = r"C:\Users\carlo\Downloads\analysis-20221207T102828Z-001\analysis"
    folders = listdir(root_path)
    paths = [os.path.join(root_path , ii) for ii in folders]
    df_list = []
    for path in paths:
        if os.path.isdir(path):
            for f in listdir(path):
                data = pd.read_csv(join(path, f)).drop('Unnamed: 0',axis=1)
                folder = path.split('/')[-1]
                data['folder'] = folder
                isGamma = folder.find("gamma")
                if isGamma > -1:
                    data['gamma'] = 0.9
                else:
                    data['gamma'] = 0.4
                data['filename'] = f.split('.')[0].split('_')[0]
                data['period'] = f.split('.')[0].split('_')[-1]
                df_list.append(data)
    df = pd.concat(df_list)
    return df

# %%
df.gamma.value_counts()

# %%
df=df[(df["filename"]=="TDQN") | (df["filename"]=="TDRQN")]


stocks_col = ['Google', 'Apple', 'IBM', 'Baidu',
           'JPMorgan Chase', 'BlackRock', 'ExxonMobil', 'Volkswagen', 'Toyota',
           'Coca Cola', 'McDonalds']
    
df.loc[1,stocks_col] = df.loc[1,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[2,stocks_col] = df.loc[2,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[5,stocks_col] = df.loc[5,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df.loc[6,stocks_col] = df.loc[6,stocks_col].apply(lambda x: [ii.strip(' days') if type(ii)==str else ii for ii in x])
df.loc[7,stocks_col] = df.loc[7,stocks_col].apply(lambda x: [ii.strip('%') if type(ii)==str else ii for ii in x])
df[stocks_col] = df[stocks_col].astype(float)
df['mean'] = df[stocks_col].apply(np.mean,axis=1)
df['var'] = df[stocks_col].apply(np.var,axis=1)

# %%
df.groupby(by=["filename","gamma"]).median()

# %%
    j="Annualized Return"
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period","gamma"]]=df_vo[[i,"folder","filename","period","gamma"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    df_vo1=df_vo1[(df_vo1["period"]=="0") | (df_vo1["period"]=="1")]
    df_vo1.rename(columns={"Value": "Annualized Return"},inplace=True)
    df_vo1.rename(columns={"filename": "Algorithm"},inplace=True)
    sns.boxplot(data=df_vo1, x="gamma", y="Annualized Return", hue="Algorithm", showfliers = False, palette="viridis")

# %%
df_vo1=df_vo1[(df_vo1["period"]=="0") | (df_vo1["period"]=="1")]

# %%
df_vo1.rename(columns={"Value": "Annualized Return"},inplace=True)
df_vo1.rename(columns={"filename": "Algorithm"},inplace=True)

# %%
sns.boxplot(data=df_vo1, x="gamma", y="Annualized Return", hue="Algorithm", showfliers = False, palette="viridis")
plt.xlabel("Discount Factor ($\gamma$)")
plt.legend(loc='lower right')

# %%
df_vo1

# %%
    j="Annualized Volatility"
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period","gamma"]]=df_vo[[i,"folder","filename","period","gamma"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    df_vo1=df_vo1[(df_vo1["period"]=="0") | (df_vo1["period"]=="1")]
    df_vo1.rename(columns={"Value": "Annualized Volatility"},inplace=True)
    df_vo1.rename(columns={"filename": "Algorithm"},inplace=True)
    sns.boxplot(data=df_vo1, x="gamma", y="Annualized Volatility", hue="Algorithm", showfliers = False, palette="viridis")
    plt.xlabel("Discount Factor ($\gamma$)")
    plt.legend(loc='lower right')

# %%
sns.boxplot(data=df_vo1, x="gamma", y="Annualized Volatility", hue="Algorithm", showfliers = False, palette="viridis")
plt.xlabel("Discount Factor ($\gamma$)")
plt.legend(loc='upper right')

# %% [markdown]
# ### Context

# %%
df["Context"]="Context"
df["Context"].where(df['folder'].str.contains('no context'),"No Context",inplace=True)

# %%
df.Context.value_counts()

# %%
    j="Annualized Return"
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period","Context"]]=df_vo[[i,"folder","filename","period","Context"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    df_vo1=df_vo1[(df_vo1["period"]=="0") | (df_vo1["period"]=="1")]
    df_vo1.rename(columns={"Value": "Annualized Return"},inplace=True)
    df_vo1.rename(columns={"filename": "Algorithm"},inplace=True)
    sns.boxplot(data=df_vo1, x="Context", y="Annualized Return", hue="Algorithm", showfliers = False, palette="viridis")

# %%
    j="Annualized Volatility"
    df_vo=df[df["Performance Indicator"]==j]
    df_vo=df_vo[(df_vo.period != "TDQN") & (df_vo.period != "TDRQN") & (df_vo.period != "3")]

    df_temp=pd.DataFrame()
    df_vo1=pd.DataFrame()
    for i in cols_to_anal:
        df_temp[["Value","folder","filename","period","Context","gamma"]]=df_vo[[i,"folder","filename","period","Context","gamma"]]
        df_vo1=pd.concat([df_vo1,df_temp])
    df_vo1=df_vo1[(df_vo1["period"]=="0") | (df_vo1["period"]=="1")]
    df_vo1.rename(columns={"Value": "Annualized Volatility"},inplace=True)
    df_vo1.rename(columns={"filename": "Algorithm"},inplace=True)
    sns.boxplot(data=df_vo1, x="Context", y="Annualized Volatility", hue="Algorithm", showfliers = False, palette="viridis")
